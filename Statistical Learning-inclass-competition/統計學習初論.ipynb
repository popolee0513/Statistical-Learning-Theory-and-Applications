# %%
import pandas as pd
data=pd.read_excel("C://Users//POPO//Desktop//train.xlsx")
test=pd.read_excel("C://Users//POPO//Desktop//test.xlsx")

# %%
data["k_a08a_1"]=data["k_a08a_1"].replace("無","")
data["k_a08a_2"]=data["k_a08a_2"].replace("無","")
data["k_a08a_3"]=data["k_a08a_3"].replace("無","")
data["k_a08a_4"]=data["k_a08a_4"].replace("無","")
data["k_a08a_5"]=data["k_a08a_5"].replace("無","")
data["k_a08a_1"]=data["k_a08a_1"].replace("不知道","")
data["k_a08a_2"]=data["k_a08a_2"].replace("不知道","")
data["k_a08a_3"]=data["k_a08a_3"].replace("不知道","")
data["k_a08a_4"]=data["k_a08a_4"].replace("不知道","")
data["k_a08a_5"]=data["k_a08a_5"].replace("不知道","")

# %%
test["k_a08a_1"]=test["k_a08a_1"].replace("無","")
test["k_a08a_2"]=test["k_a08a_2"].replace("無","")
test["k_a08a_3"]=test["k_a08a_3"].replace("無","")
test["k_a08a_4"]=test["k_a08a_4"].replace("無","")
test["k_a08a_5"]=test["k_a08a_5"].replace("無","")
test["k_a08a_1"]=test["k_a08a_1"].replace("不知道","")
test["k_a08a_2"]=test["k_a08a_2"].replace("不知道","")
test["k_a08a_3"]=test["k_a08a_3"].replace("不知道","")
test["k_a08a_4"]=test["k_a08a_4"].replace("不知道","")
test["k_a08a_5"]=test["k_a08a_5"].replace("不知道","")

# %%
data.head()
# Out:
#       x01  a08a01  a08a02     k_a08a_1 k_a08a_2 k_a08a_3 k_a08a_4 k_a08a_5  \
# 0  100202      47    4311       大潤發總公司      大賣場      會計部       會計     總計發票
# 1  100221      47    5140  台灣資生堂股份有限公司    化粧品販售              美容顧問  販售化粧品護膚
# 2  100401      26    7993         宏偉科技     Ic加工       品管             檢查完成品
# 3  100411      56    5296     台灣第一家塩酥雞       食物                       炸料收錢
# 4  100421      47    5220         统一超商    零售日用品                店員   收銀排貨售貨
#
#    fix
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0

# %%
import re
def remove_punctuation(line):
    rule = re.compile(r"[^a-zA-Z\u4e00-\u9fa5]")
    line = rule.sub('',line)
    return line

# %%
data["k_a08a_1"]=data["k_a08a_1"].apply(remove_punctuation)
data["k_a08a_2"]=data["k_a08a_2"].apply(remove_punctuation)
data["k_a08a_3"]=data["k_a08a_3"].apply(remove_punctuation)
data["k_a08a_4"]=data["k_a08a_4"].apply(remove_punctuation)
data["k_a08a_5"]=data["k_a08a_5"].apply(remove_punctuation)

# %%
test["k_a08a_1"]=test["k_a08a_1"].apply(remove_punctuation)
test["k_a08a_2"]=test["k_a08a_2"].apply(remove_punctuation)
test["k_a08a_3"]=test["k_a08a_3"].apply(remove_punctuation)
test["k_a08a_4"]=test["k_a08a_4"].apply(remove_punctuation)
test["k_a08a_5"]=test["k_a08a_5"].apply(remove_punctuation)

# %%
data["k_a08a_4"]=data["k_a08a_4"].apply(lambda x:x.replace("闆","板"))
test["k_a08a_4"]=test["k_a08a_4"].apply(lambda x:x.replace("闆","板"))

# %%
remove=["人員","辦理","負責","所有","偶爾","工作","從事","為主","事務","及","與","的"
        ,"多主","為輔","主要","幫忙","大大小小","左右","知道","永遠","相關","現場","其他","一般","將須"
       ,"lOO人以上公司","因剛換所以不清楚","只知要不停和外國客戶","詳細不願多說","攻牙要職前訓練","一定","務亦為","十人","三百人"
       ,"但人數不知什麼都不","內容","主以","十多人","對外","大約人","多位","九人","台灣","美國","很少","兒子"
       ,"先生","嫂嫂","太太","媽媽","自己","然後","只知","不知","九百多","別人","一打","一幫","方式","並且"
       ,"各種","固定","整個","實際","一人設","一切","然後","居多","中平","地方","各式","並兼","根據","以下"
       ,"以內","也","之類","不斷","有關","員工約人","各項","蘇州區域","沒有","一放樣","一年多","部分","重家裏"
       ,"量力做一點","以電話","約位","另兩位","女兒","小時生活","現有","一個","人以上","拿民眾","小五到國三",
       "不能詳述","父親","紗在辨公室","叫他做什麼就做什麼","不須要管人","四人","組員有時人參予","到機車行為機車定檢儀器",'丶',
       "館內","第一線","至","確保","狀況","ICHOUSEHONEYWELL","霍爾",'Apple','ivancomper',
       '牙醫器材設備販售到牙醫診所',"白河區的","的都有做","數種",'第四','關廟','心開','泰國',"一氣","以","什貨",
       "廠辦大樓","共同","亢","一賣","幫助","機構","文文步",'一行','一產一','中西','YMRT',"五甲","直轄一",'筆記型'
       ,'三支',"信義","亞太","北區","中正一","北二區","桃園市","中壢店","台東分公司東市","南彰","三天中","嘉義","大園"
       ,"七股區","營四組","第一","直效","南區","門安規","松山展業","岡山站","工十之一","黃光二","北屯崇德",'蘆洲區','中區'
       ,"上片門","興南",'Sogo',"國際","屏東","台南","高雄","台中","新竹"]
for i in remove:
    data["k_a08a_4"]=data["k_a08a_4"].apply(lambda x:x.replace(i,""))
    test["k_a08a_4"]=test["k_a08a_4"].apply(lambda x:x.replace(i,""))
    data["k_a08a_5"]=data["k_a08a_5"].apply(lambda x:x.replace(i,""))
    test["k_a08a_5"]=test["k_a08a_5"].apply(lambda x:x.replace(i,""))
    data["k_a08a_2"]=data["k_a08a_2"].apply(lambda x:x.replace(i,""))
    test["k_a08a_2"]=test["k_a08a_2"].apply(lambda x:x.replace(i,""))
    data["k_a08a_3"]=data["k_a08a_3"].apply(lambda x:x.replace(i,""))
    test["k_a08a_3"]=test["k_a08a_3"].apply(lambda x:x.replace(i,""))

# %%
data["k_a08a_3"]=data["k_a08a_3"].apply(lambda x:x.replace("部",""))
test["k_a08a_3"]=test["k_a08a_3"].apply(lambda x:x.replace("部",""))

data["k_a08a_3"]=data["k_a08a_3"].apply(lambda x:x.replace("課",""))
test["k_a08a_3"]=test["k_a08a_3"].apply(lambda x:x.replace("課",""))

# %%
with open("vocabulary.txt", "w",encoding="utf-8") as text_file:
    text_file.write("新陳代謝\n")
    text_file.write("製藥\n")
    text_file.write("鐵路\n")
    text_file.write("秘書\n")
    text_file.write("茶飲店\n")
    text_file.write("紅豆湯\n")
    text_file.write("晶元\n")
    text_file.write("建築物\n")
    text_file.write("中西藥\n")
    text_file.write("農作務\n")
    text_file.write("幼兒\n")
    text_file.write("藥膏\n")
    text_file.write("文具\n")
    text_file.write("初等\n")
    text_file.write("中等\n")
    text_file.write("國防\n")
    text_file.write("五金\n")
    text_file.write("配件\n")
    text_file.write("捲釘\n")
    text_file.write("保健\n")
    text_file.write("消費\n")
    text_file.write("財務\n")
    text_file.write("竹筍\n")
    text_file.write("白鐵\n")
    text_file.write("保全\n")
    text_file.write("特殊\n")
    text_file.write("茶行\n")
    text_file.write("牛仔褲\n")
    text_file.write("畫版\n")
    text_file.write("水管道\n")
    text_file.write("工程\n")
    text_file.write("特質\n")
    text_file.write("應收\n")
    text_file.write("應付款\n")
    text_file.write("學生\n")
    text_file.write("地理\n")
    text_file.write("檢查\n")
    text_file.write("哲學\n")
    text_file.write("自然科\n")
    text_file.write("美妝\n")
    text_file.write("美睫\n")
    text_file.write("配置\n")
    text_file.write("蔬菜\n")
    text_file.write("水果\n")
    text_file.write("家電\n")
    text_file.write("多餘\n")
    text_file.write("導師\n")
    text_file.write("兒童\n")
    text_file.write("廠務\n")
    text_file.write("鋸斷\n")
    text_file.write("撿貨\n")
    text_file.write("包貨\n")
    text_file.write("麵店\n")
    text_file.write("行政\n")
    text_file.write("抹平\n")
    text_file.write("拌水泥\n")
    text_file.write("體育\n")
    text_file.write("歷吏\n")
    text_file.write("藥劑師\n")
    text_file.write("笆樂\n")
    text_file.write("管理人\n")
    text_file.write("店員\n")
    text_file.write("客戶端\n")
    text_file.write("葉子\n")
    text_file.write("排程\n")
    text_file.write("超商\n")
    text_file.write("女裝\n")
    text_file.write("打臨工\n")
    text_file.write("東西\n")
    text_file.write("色捲布\n")
    text_file.write("場地\n")
    text_file.write("蔬菓\n")
    text_file.write("家裡\n")
    text_file.write("辦公室\n")
    text_file.write("針對\n")
    text_file.write("高職生\n")
    text_file.write("市場\n")
    text_file.write("河粉\n")
    text_file.write("跟隨\n")
    text_file.write("別人\n")
    text_file.write("老師\n")
    text_file.write("師父\n")
    text_file.write("人事\n")
    text_file.write("管理\n")
    text_file.write("機電\n")
    text_file.write("執行\n")
    text_file.write("社會\n")
    text_file.write("餐點\n")
    text_file.write("幫忙\n")
    text_file.write("收帳\n")
    text_file.write("文宣\n")
    text_file.write("憑單\n")
    text_file.write("檢錄\n")
    text_file.write("幼兒園\n")
    text_file.write("醫衛\n")
    text_file.write("急診室\n") 
    text_file.write("小客車\n")
    text_file.write("賣茶\n")
    text_file.write("顧\n")
    text_file.write("大貨車\n")
    text_file.write("炸抬手\n")
    text_file.write("完成品\n")
    text_file.write("房仲\n")
    text_file.write("存放款\n")
    text_file.write("洗腎機\n")
    text_file.write("銷售員\n")
    text_file.write("護理師\n")
    text_file.write("批發\n")
    text_file.write("業務員\n")
    text_file.write("工程師\n")
    text_file.write("士官長\n")
    text_file.write("包裝員\n")
    text_file.write("美髮師\n")
    text_file.write("分隊長\n")
    text_file.write("照顧員\n")
    text_file.write("操作員\n")
    text_file.write("會計師\n")
    text_file.write("理髮師\n")
    text_file.write("保險\n")
    text_file.write("研究員\n")
    text_file.write("補習班\n")
    text_file.write("紙箱\n")
    text_file.write("包裝員\n")
    text_file.write("經理\n")
    text_file.write("美容師\n")
    text_file.write("炸枱手\n")
    text_file.write("木工師\n")
    text_file.write("副營長\n")
    text_file.write("外包\n")
    text_file.write("烘焙師\n")
    text_file.write("副廠長\n")
    text_file.write("專案\n")
    text_file.write("製作人\n")
    text_file.write("髮型\n")
    text_file.write("製圖師\n")
    text_file.write("製圖\n")
    text_file.write("稽核員\n")
    text_file.write("炒麵\n")
    text_file.write("副處長\n")
    text_file.write("研究\n")
    text_file.write("助理\n")
    text_file.write("物料員\n")
    text_file.write("秘書\n")
    text_file.write("褓姆\n")
    text_file.write("副理\n")
    text_file.write("小隊長\n")
    text_file.write("員警\n")
    text_file.write("麵包\n")
    text_file.write("師傅\n")
    text_file.write("管理員\n")
    text_file.write("技師\n")
    text_file.write("造型師\n")
    text_file.write("櫃檯\n")
    text_file.write("副主任\n")
    text_file.write("分析師\n")
    text_file.write("管理師\n")
    text_file.write("品管員\n")
    text_file.write("主任\n")
    text_file.write("副組長\n")
    text_file.write("行銷員\n")
    text_file.write("護士\n")
    text_file.write("送貨\n")
    text_file.write("操作\n")
    text_file.write("系統\n")
    text_file.write("課長\n")
    text_file.write("臨時工\n")
    text_file.write("教師\n")
    text_file.write("客服\n")
    text_file.write("敎師\n")
    text_file.write("組長\n")
    text_file.write("約僱\n")
    text_file.write("專任\n")
    text_file.write("作業員\n")
    text_file.write("水泥匠\n")
    text_file.write("配送員\n")
    text_file.write("設計\n")
    text_file.write("消防員\n")
    text_file.write("外包\n")
    text_file.write("製程\n")
    text_file.write("製造\n")
    text_file.write("自耕農\n")
    text_file.write("養蚵員\n")
    text_file.write("專任\n")
    text_file.write("賣菜\n")
    text_file.write("副總\n")
    text_file.write("經理\n")
    text_file.write("設計師\n")
    text_file.write("美髮\n")
    text_file.write("吧檯\n")
    text_file.write("經紀人\n")
    text_file.write("研發\n")
    text_file.write("繪圖員\n")
    text_file.write("董事長\n")
    text_file.write("跟診\n")
    text_file.write("人員\n")
    text_file.write("採收\n")
    text_file.write("揀葉\n")
    text_file.write("修護\n")
    text_file.write("研究\n")
    text_file.write("部門\n")
    text_file.write("証照\n")
    text_file.write("操做\n")
    text_file.write("會計\n")
    text_file.write("技術員\n")
    text_file.write("員工\n")
    text_file.write("註冊\n")
    text_file.write("職稱\n")
    text_file.write("專科\n")
    text_file.write("律師\n")
    text_file.write("證照\n")
    text_file.write("營業員\n")
    text_file.write("化粧品\n")
    text_file.write("護膚\n")
    text_file.write("行銷\n")
    text_file.write("業務\n")
    text_file.write("大客車\n")
    text_file.write("機枱\n")
    text_file.write("維修\n")
    text_file.write("國中\n")
    text_file.write("國小\n")
    text_file.write("小學\n")
    text_file.write("計程車\n")
    text_file.write("載運\n")
    text_file.write("學生\n")
    text_file.write("教學\n")
    text_file.write("燙髮\n")
    text_file.write("推廣\n")
    text_file.write("駕駛\n")
    text_file.write("賣場\n")
    text_file.write("不用管人\n")
    text_file.write("馬達\n")
    text_file.write("電路\n")
    text_file.write("製作\n")
    text_file.write("檢修\n")
    text_file.write("品質\n")
    text_file.write("分級\n")
    text_file.write("報表\n")
    text_file.write("樓層\n")
    text_file.write("維護\n")
    text_file.write("安裝\n")
    text_file.write("不銹鋼\n")
    text_file.write("門窗\n")
    text_file.write("社區\n")
    text_file.write("辦理\n")
    text_file.write("婦女\n")
    text_file.write("個人\n")
    text_file.write("挖土機\n")
    text_file.write("理髮\n")
    text_file.write("農作物\n")
    text_file.write("運送\n")
    text_file.write("貨物\n")
    text_file.write("油雞\n")
    text_file.write("醉雞\n")
    text_file.write("裝修\n")
    text_file.write("水電\n")
    text_file.write("冷氣\n")
    text_file.write("空調\n")
    text_file.write("電力\n")
    text_file.write("洗腎\n")
    text_file.write("打掃\n")
    text_file.write("沖床\n")
    text_file.write("客戶\n")
    text_file.write("訂製\n")
    text_file.write("網版\n")
    text_file.write("處理\n")
    text_file.write("訂單\n")
    text_file.write("買賣\n")
    text_file.write("機枱\n")
    text_file.write("校內\n")
    text_file.write("產品\n")
    text_file.write("為輔\n")
    text_file.write("進出貨\n")
    text_file.write("機枱\n")
    text_file.write("調製\n")
    text_file.write("介紹\n")
    text_file.write("機枱\n")
    text_file.write("部門\n")
    text_file.write("打針\n")
    text_file.write("點滴\n")
    text_file.write("餐飲\n")
    text_file.write("便當\n")
    text_file.write("銷售\n")
    text_file.write("學生\n")
    text_file.write("家長\n")
    text_file.write("參與\n")
    text_file.write("機枱\n")
    text_file.write("遊覽車\n")
    text_file.write("報價單\n")
    text_file.write("資料\n")
    text_file.write("為主\n")
    text_file.write("開發\n")
    text_file.write("辦理\n")
    text_file.write("手續\n")
    text_file.write("大客車\n")
    text_file.write("現金\n")
    text_file.write("打掃\n")
    text_file.write("機台\n")
    text_file.write("駕駛\n")
    text_file.write("小貨車\n")
    text_file.write("下單\n")
    text_file.write("訂貨\n")
    text_file.write("帶人\n")
    text_file.write("編製\n")
    text_file.write("預算\n")
    text_file.write("指導\n")
    text_file.write("聯結車\n")
    text_file.write("車箱\n")
    text_file.write("台電\n")
    text_file.write("機台\n")
    text_file.write("調查\n")
    text_file.write("室內\n")
    text_file.write("裝修\n")
    text_file.write("裝潢\n")
    text_file.write("搶救\n")
    text_file.write("長官\n")
    text_file.write("申請\n")
    text_file.write("有無\n")
    text_file.write("管人\n")
    text_file.write("推廣\n")
    text_file.write("陳列\n")
    text_file.write("會議\n")
    text_file.write("業務\n")
    text_file.write("聯繫\n")
    text_file.write("進口\n")
    text_file.write("供應商\n")
    text_file.write("印表機\n")
    text_file.write("電信\n")
    text_file.write("洗髮\n")
    text_file.write("剪髮\n")
    text_file.write("說明\n")
    text_file.write("產品\n")
    text_file.write("辦公室\n")
    text_file.write("冷飲\n")
    text_file.write("出貨\n")
    text_file.write("順序\n")
    text_file.write("理髮\n")
    text_file.write("堆高機\n")
    text_file.write("事務\n")
    text_file.write("協助\n")
    text_file.write("傷患\n")
    text_file.write("外海\n")
    text_file.write("巡邏\n")
    text_file.write("教學\n")
    text_file.write("師生\n")
    text_file.write("製做\n")
    text_file.write("法規\n")
    text_file.write("製定\n")
    text_file.write("排貨\n")
    text_file.write("售貨\n")
    text_file.write("垃圾車\n")
    text_file.write("收垃圾\n")
    text_file.write("通過\n")
    text_file.write("查審\n")
    text_file.write("稅務\n")
    text_file.write("人事\n")
    text_file.write("第一線\n")
    text_file.write("漁港\n")
    text_file.write("負責\n")
    text_file.write("監工\n")
    text_file.write("矽膠\n")
    text_file.write("辦公室\n")
    text_file.write("軟硬體\n")
    text_file.write("彙整\n")
    text_file.write("機枱\n")
    text_file.write("派工\n")
    text_file.write("生產線\n")
    text_file.write("計算\n")
    text_file.write("製麵\n")
    text_file.write("顧店\n")
    text_file.write("生產\n")
    text_file.write("圖文\n")
    text_file.write("海報\n")
    text_file.write("拍賣\n")
    text_file.write("講解\n")
    text_file.write("韌體\n")
    text_file.write("幼稚園\n")
    text_file.write("實行\n")
    text_file.write("期貨\n")
    text_file.write("核對\n")
    text_file.write("後勤\n")
    text_file.write("補給\n")
    text_file.write("休旅車\n")
    text_file.write("獎金\n")
    text_file.write("結算\n")
    text_file.write("種植\n")
    text_file.write("水餃\n")
    text_file.write("驗證\n")
    text_file.write("營養\n")
    text_file.write("彩妝\n")
    text_file.write("銀行\n")
    text_file.write("追蹤\n")
    text_file.write("金屬\n")
    text_file.write("製品\n")
    text_file.write("營收\n")
    text_file.write("記帳士\n")
    text_file.write("客製化\n")
    text_file.write("代購\n")
    text_file.write("廠商\n")
    text_file.write("生產\n")
    text_file.write("改善\n")
    text_file.write("良率\n")
    text_file.write("外場\n")
    text_file.write("服務\n")
    text_file.write("用藥\n")
    text_file.write("檸檬\n")
    text_file.write("販售\n")
    text_file.write("鐵捲門\n")
    text_file.write("飲料\n")
    text_file.write("輔導\n")
    text_file.write("製品\n")
    text_file.write("大卡車\n")
    text_file.write("批貨\n")
    text_file.write("品檢\n")
    text_file.write("舖貨\n")
    text_file.write("國外\n")
    text_file.write("冰塊\n")
    text_file.write("煎台\n")
    text_file.write("記帳\n")
    text_file.write("彩粧\n")
    text_file.write("接聽\n")
    text_file.write("櫃台\n")
    text_file.write("受訪者\n")
    text_file.write("養蝦\n")
    text_file.write("農民\n")
    text_file.write("用水\n")
    text_file.write("排水\n")
    text_file.write("輸送帶\n")
    text_file.write("績效\n")
    text_file.write("標籤\n")
    text_file.write("認証\n")
    text_file.write("對帳\n")
    text_file.write("收發\n")
    text_file.write("部門\n")
    text_file.write("試做\n")
    text_file.write("營運\n")
    text_file.write("驗証\n")
    text_file.write("理專\n")
    text_file.write("售後\n")
    text_file.write("後續\n")
    text_file.write("資訊\n")
    text_file.write("老闆\n")
    text_file.write("機械\n")
    text_file.write("美術\n")
    text_file.write("機臺\n")
    text_file.write("成品\n")
    text_file.write("檢驗\n")
    text_file.write("招攬\n")
    text_file.write("聯絡\n")
    text_file.write("鷹架\n")
    text_file.write("金流\n")
    text_file.write("櫃枱\n")
    text_file.write("櫃枱\n")
    text_file.write("看診\n")
    text_file.write("病歷\n")
    text_file.write("出缺勤\n")
    text_file.write("薪資\n")
    text_file.write("船員\n")
    text_file.write("上課\n")
    text_file.write("學生\n")
    text_file.write("敎學\n")
    text_file.write("敎學\n")
    text_file.write("寫程式\n")
    text_file.write("審核\n")
    text_file.write("合約\n")
    text_file.write("照服員\n")
    text_file.write("報單\n")
    text_file.write("驗貨\n")
    text_file.write("諮詢\n")
    text_file.write("路線\n")
    text_file.write("原物料\n")
    text_file.write("產線\n")
    text_file.write("總務\n")
    text_file.write("臨時\n")
    text_file.write("產婦\n")
    text_file.write("照顧\n")
    text_file.write("魚塭\n")
    text_file.write("吳郭魚\n")
    text_file.write("前製\n")
    text_file.write("準備\n")
    text_file.write("排程\n")
    text_file.write("生產\n")
    text_file.write("投資\n")
    text_file.write("理財\n")
    text_file.write("收銀\n")
    text_file.write("給料\n")
    text_file.write("搬東西\n")
    text_file.write("體力工\n")
    text_file.write("狀況\n")
    text_file.write("叫貨\n")
    text_file.write("收錢\n")
    text_file.write("機檯\n")
    text_file.write("報價\n")
    text_file.write("詢價\n")
    text_file.write("送審\n")
    text_file.write("開立\n")
    text_file.write("出廠\n")
    text_file.write("管製\n")
    text_file.write("炸鷄\n")
    text_file.write("煮麵\n")
    text_file.write("賣麵\n")
    text_file.write("可靠度\n")
    text_file.write("貨物\n")
    text_file.write("電子\n")
    text_file.write("文書\n")
    text_file.write("鍵檔\n")
    text_file.write("飯糰\n")
    text_file.write("美粧品\n")
    text_file.write("配電\n")
    text_file.write("蔥油餅\n")
    text_file.write("保護短管\n")
    text_file.write("鋼構網膜\n")
    text_file.write("架設\n")
    text_file.write("化學皮墊\n")
    text_file.write("線上\n")
    text_file.write("憑証\n")
    text_file.write("統一超商\n")
    text_file.write("關係\n")
    text_file.write("維繫\n")
    text_file.write("會勘\n")
    text_file.write("呈報\n")
    text_file.write("蓮藕\n")
    text_file.write("頭髮\n")
    text_file.write("麵粉\n")
    text_file.write("收銀\n")
    text_file.write("種蔥\n")
    text_file.write("剪蔥頭\n")
    text_file.write("顧客\n")
    text_file.write("來電\n")
    text_file.write("壞掉\n")
    text_file.write("雞隻\n")
    text_file.write("出入院\n")
    text_file.write("科學\n")
    text_file.write("飯捲\n")
    text_file.write("在家裡\n")
    text_file.write("煮飯\n")
    text_file.write("寺眾\n")
    text_file.write("遊客\n")
    text_file.write("安親班\n")
    text_file.write("督導\n")
    text_file.write("區域性\n")
    text_file.write("推銷\n")
    text_file.write("牙醫\n")
    text_file.write("抬拳道\n")
    text_file.write("人資\n")
    text_file.write("產線\n")
    text_file.write("砂石車\n")
    text_file.write("複查\n")
    text_file.write("摩托車\n")
    text_file.write("製油\n")
    text_file.write("緊急\n")
    text_file.write("救護\n")
    text_file.write("太空包\n")
    text_file.write("窗簾\n")
    text_file.write("廠房\n")
    text_file.write("復健用\n")
    text_file.write("医療带\n")
    text_file.write("國文\n")
    text_file.write("時薪制\n")
    text_file.write("產線\n")
    text_file.write("國一\n")
    text_file.write("諮商\n")
    text_file.write("語文\n")
    text_file.write("在家裡\n")
    text_file.write("別人\n")
    text_file.write("長途\n")
    text_file.write("開會\n")
    text_file.write("客製化\n")
    text_file.write("不良品\n")
    text_file.write("零售\n")
    text_file.write("做臉\n")
    text_file.write("配送\n")
    text_file.write("貨品\n")
    text_file.write("搬運\n")
    text_file.write("電路板\n")
    text_file.write("委託\n")
    text_file.write("從事\n")
    text_file.write("大巴士\n")
    text_file.write("服務台\n")
    text_file.write("拉鍊\n")
    text_file.write("荖葉\n")
    text_file.write("分類\n")
    text_file.write("鐵製品\n")
    text_file.write("汽車\n")
    text_file.write("頗面圖\n")
    text_file.write("報告書\n")
    text_file.write("隔間圖\n")
    text_file.write("平立圖\n")
    text_file.write("驗貨\n")
    text_file.write("滷味\n")
    text_file.write("舖設\n")
    text_file.write("地磚\n")
    text_file.write("生薑\n")
    text_file.write("鋁門窗\n")
    text_file.write("貨品\n")
    text_file.write("倉庫\n")
    text_file.write("印刷機\n")
    text_file.write("海產\n")
    text_file.write("蚵子煎\n")
    text_file.write("對帳\n")
    text_file.write("鐵工\n")
    text_file.write("燒焊\n")
    text_file.write("無塵室\n")
    text_file.write("流水帳\n")
    text_file.write("原物料\n")
    text_file.write("詢價\n")
    text_file.write("臺語\n")
    text_file.write("工地\n")
    text_file.write("土水工\n")
    text_file.write("早午餐\n")
    text_file.write("網拍\n")
    text_file.write("機臺\n")
    text_file.write("鐵板燒\n")
    text_file.write("師父\n")
    text_file.write("電子板\n")
    text_file.write("售後\n")
    text_file.write("月報\n")
    text_file.write("傢俱\n")
    text_file.write("修復\n")
    text_file.write("華碩\n")
    text_file.write("顧客\n")
    text_file.write("外送\n")
    text_file.write("繪製\n")
    text_file.write("庫存\n")
    text_file.write("菜市場\n")
    text_file.write("低年級\n")
    text_file.write("封口機\n")
    text_file.write("包裝\n")
    text_file.write("床墊\n")
    text_file.write("規劃\n")
    text_file.write("製成\n")
    text_file.write("護理\n")
    text_file.write("庫存\n")
    text_file.write("扶手梯\n")
    text_file.write("輭體\n")
    text_file.write("連繫\n")
    text_file.write("註冊\n")
    text_file.write("成績\n")
    text_file.write("打菜\n")
    text_file.write("化學\n")
    text_file.write("窗簾\n")
    text_file.write("修擅\n")
    text_file.write("魚丸\n")
    text_file.write("偷用地\n")
    text_file.write("外邦\n")
    text_file.write("韌體\n")
    text_file.write("銑床\n")
    text_file.write("土水師\n")
    text_file.write("封裝\n")
    text_file.write("晶圓\n")
    text_file.write("照明燈\n")
    text_file.write("國中小\n")
    text_file.write("快炒\n")
    text_file.write("進出口\n")
    text_file.write("半導體\n")
    text_file.write("化粧\n")
    text_file.write("醫治\n")
    text_file.write("病人\n")
    text_file.write("成衣\n")
    text_file.write("復健\n")
    text_file.write("筆電\n")
    text_file.write("冷軋成型機\n")
    text_file.write("被動元件\n")
    text_file.write("光纖接頭\n")
    text_file.write("太陽能板\n")
    text_file.write("敎育\n")
    text_file.write("事務機\n")
    text_file.write("電腦\n")
    text_file.write("手機\n")
    text_file.write("遊戲\n")
    text_file.write("輪胎\n")
    text_file.write("不鏽鋼\n")
    text_file.write("真空管路\n")
    text_file.write("有機\n") 
    text_file.write("網路\n")
    text_file.write("電線\n")
    text_file.write("電方纜\n")
    text_file.write("破壞性\n")
    text_file.write("活體\n")
    text_file.write("海鮮\n")
    text_file.write("課後\n")
    text_file.write("橋梁\n")
    text_file.write("棉花糖\n")
    text_file.write("照相機\n")
    text_file.write("跑步機\n")
    text_file.write("實劑\n")
    text_file.write("所需\n")
    text_file.write("量販店\n")
    text_file.write("高低壓配電盤\n")
    text_file.write("自行車\n")
    text_file.write("乳製品\n")
    text_file.write("影印機\n")
    text_file.write("網路\n")
    text_file.write("馬桶\n")
    text_file.write("板模\n")
    text_file.write("建築\n")
    text_file.write("營造\n")
    text_file.write("長期\n")
    text_file.write("照護\n")
    text_file.write("秀珍菇\n")
    text_file.write("才藝\n")
    text_file.write("補習\n")
    text_file.write("批發\n")
    text_file.write("鈑金\n")
    text_file.write("製銷\n")
    text_file.write("儲匯\n")
    text_file.write("監督\n")
    text_file.write("感應器\n")
    text_file.write("通訊\n")
    text_file.write("製版\n")
    text_file.write("藥品\n")
    text_file.write("電源供應器\n")
    text_file.write("產品\n")
    text_file.write("代工\n")
    text_file.write("隨身碟\n")
    text_file.write("清洗\n")
    text_file.write("纲拍\n")
    text_file.write("洗淨\n")
    text_file.write("水菓\n")
    text_file.write("手錶\n")
    text_file.write("産品\n")
    text_file.write("肉鬆\n")
    text_file.write("淨水器\n")
    text_file.write("烤漆\n")
    text_file.write("國防部\n")
    text_file.write("農産品\n")
    text_file.write("起重機\n")
    text_file.write("運送\n")
    text_file.write("機器\n")
    text_file.write("釋迦\n")
    text_file.write("運輸\n")
    text_file.write("營造\n")
    text_file.write("芭樂\n")
    text_file.write("批發\n")
    text_file.write("農產品\n")
    text_file.write("血糖機\n")
    text_file.write("飛航\n")
    text_file.write("天氣\n")
    text_file.write("預測報\n")
    text_file.write("多媒體\n")
    text_file.write("月子\n")
    text_file.write("後備\n")
    text_file.write("量測\n")
    text_file.write("設備\n")
    text_file.write("製鞋\n")
    text_file.write("鋼鐵\n")
    text_file.write("貨運\n")
    text_file.write("太空袋\n")
    text_file.write("工具機\n")
    text_file.write("午晚餐\n")
    text_file.write("服務\n")
    text_file.write("台南\n")
    text_file.write("小學生\n")
    text_file.write("種花\n")
    text_file.write("板模\n")
    text_file.write("鋼骨\n")
    text_file.write("架構\n")
    text_file.write("病患\n")
    text_file.write("稻\n")
    text_file.write("免洗杯\n")
    text_file.write("免洗碗\n")
    text_file.write("咖啡機\n")
    text_file.write("通路商\n")
    text_file.write("旅遊\n")
    text_file.write("翻譯\n")
    text_file.write("信託\n")
    text_file.write("蔥油餅\n")
    text_file.write("積體電路\n")
    text_file.write("諾麗果\n")
    text_file.write("民衆\n")
    text_file.write("生産\n")
    text_file.write("烤肉架\n")
    text_file.write("保溫杯\n")
    text_file.write("不綉鋼\n")
    text_file.write("不綉鋼\n")
    text_file.write("當歸鴨\n")
    text_file.write("熟食\n")
    text_file.write("爪蓋\n")
    text_file.write("美甲機\n")
    text_file.write("肉乾\n")
    text_file.write("販賣\n")
    text_file.write("泡棉\n")
    text_file.write("海砂屋\n")
    text_file.write("輻射屋\n")
    text_file.write("義大利麵\n")
    text_file.write("營造\n")
    text_file.write("糖葫蘆\n")
    text_file.write("天然氣\n")
    text_file.write("供應\n")
    text_file.write("客運\n")
    text_file.write("載客\n")
    text_file.write("鹹酥雞\n")
    text_file.write("螺絲\n")
    text_file.write("香菸\n")
    text_file.write("高中職\n")
    text_file.write("機油\n")
    text_file.write("經銷\n")
    text_file.write("製瓶器\n")
    text_file.write("隨身碟\n")
    text_file.write("店鋪\n")
    text_file.write("辦公室\n")
    text_file.write("採買\n")
    text_file.write("宅配\n")
    text_file.write("顯微鏡\n")
    text_file.write("連接器\n")
    text_file.write("接待\n")
    text_file.write("客人\n")
    text_file.write("火龍果\n")
    text_file.write("備料\n")
    text_file.write("新舊廠\n")
    text_file.write("數學\n")
    text_file.write("發票\n")
    text_file.write("配綫\n")
    text_file.write("改進\n")
    text_file.write("證券\n")
    text_file.write("停車場\n")
    text_file.write("出貨單\n")
    text_file.write("父親\n")
    text_file.write("工廠\n")
    text_file.write("守衛\n")
    text_file.write("農家\n")
    text_file.write("水管道\n")
    text_file.write("工程\n")
    text_file.write("點菜\n")
    text_file.write("現煮\n")
    text_file.write("提昇\n")
    text_file.write("麻糬\n")
    text_file.write("在職\n")
    text_file.write("進修\n")
    text_file.write("訓練\n")
    text_file.write("美體\n")
    text_file.write("部門\n")
    text_file.write("絲瓜棚架\n")
    text_file.write("播種\n")
    text_file.write("墻壁貼\n")
    text_file.write("歸檔\n")
    text_file.write("休息站\n")
    text_file.write("組員\n")
    text_file.write("製訂\n")
    text_file.write("說明書\n")
    text_file.write("包抬\n")
    text_file.write("黏貼\n")
    text_file.write("飾品\n")
    text_file.write("染廠\n")
    text_file.write("品質\n")
    text_file.write("壓製\n")
    text_file.write("塑膠片\n")
    text_file.write("贈與\n")
    text_file.write("佈置\n")
    text_file.write("辦活動\n")
    text_file.write("約雇\n")
    text_file.write("秘書\n")
    text_file.write("褓母\n")
    text_file.write("執照\n")
    text_file.write("軟體\n")
    text_file.write("鮪魚\n")
    text_file.write("筆墨紙硯\n")
    text_file.write("違規\n")
    text_file.write("裁罰\n")
    text_file.write("濾清器\n")
    text_file.write("壽司\n")
    text_file.write("機板\n")
    text_file.write("製避器\n")
    text_file.write("診所\n")
    text_file.write("醫美\n")
    text_file.write("貿易\n")
    text_file.write("刷卡機\n")
    text_file.write("揮發性\n")
    text_file.write("守推車\n")
    text_file.write("推車\n")
    text_file.write("昇降梯\n")
    text_file.write("清潔\n")
    text_file.write("配電盤\n")
    text_file.write("外銷\n")
    text_file.write("股票\n")
    text_file.write("里民\n")
    text_file.write("基地台\n")
    text_file.write("包包\n")
    text_file.write("皮件\n")
    text_file.write("收托\n")
    text_file.write("地區\n")
    text_file.write("機上盒\n")
    text_file.write("鏍絲\n")
    text_file.write("清潔\n")
    text_file.write("鐵製\n")
    text_file.write("鍊條\n")
    text_file.write("五穀\n")
    text_file.write("保衛\n")
    text_file.write("海軍\n")
    text_file.write("塩酥雞\n")
    text_file.write("國防\n")
    text_file.write("飯店\n")
    text_file.write("人壽\n")
    text_file.write("派出所\n")
    text_file.write("房屋\n")
    text_file.write("總經銷\n")
    text_file.write("中華民國\n")
    text_file.write("餐廳\n")
    text_file.write("大學\n")
    text_file.write("空軍\n")
    text_file.write("機場\n")
    text_file.write("基地\n")
    text_file.write("美容\n")
    text_file.write("中心\n")
    text_file.write("醫學\n")
    text_file.write("教育\n")
    text_file.write("教室\n")
    text_file.write("中藥行\n")
    text_file.write("中藥\n")
    text_file.write("市政府\n")
    text_file.write("國稅局\n")
    text_file.write("高雄\n")
    text_file.write("估價師\n")
    text_file.write("事務所\n")
    text_file.write("研究員\n")
    text_file.write("市場\n")
    text_file.write("五金\n")
    text_file.write("幼兒園\n")
    text_file.write("政府\n")
    text_file.write("塗料\n")
    text_file.write("法律\n")
    text_file.write("國際\n")
    text_file.write("影像\n")
    text_file.write("環保\n")
    text_file.write("科技\n")
    text_file.write("早餐店\n")
    text_file.write("日商\n")
    text_file.write("台灣\n")
    text_file.write("陸軍\n")
    text_file.write("醫院\n")
    text_file.write("營造\n")
    text_file.write("資訊\n")
    text_file.write("土木\n")
    text_file.write("企業\n")
    text_file.write("服飾\n")
    text_file.write("航空\n")
    text_file.write("公會\n")
    text_file.write("工會\n")
    text_file.write("治療\n")
    text_file.write("油漆\n")
    text_file.write("水產\n")
    text_file.write("玻璃\n")
    text_file.write("美語\n")
    text_file.write("交通\n")
    text_file.write("藥局\n")
    text_file.write("安養院\n")
    text_file.write("髮藝\n")
    text_file.write("捷運\n")
    text_file.write("新聞\n")
    text_file.write("光電\n")
    text_file.write("農場\n") 
    text_file.write("烤肉\n")
    text_file.write("國軍\n")
    text_file.write("學院\n")
    text_file.write("實驗\n")
    text_file.write("生物\n")
    text_file.write("中學\n")
    text_file.write("國中\n")
    text_file.write("航空\n")
    text_file.write("晶體\n")
    text_file.write("藝術\n")
    text_file.write("顧問\n")
    text_file.write("稅務\n")
    text_file.write("天主教\n")
    text_file.write("基金會\n")
    text_file.write("財團法人\n")
    text_file.write("貨運\n")
    text_file.write("髮廊\n")
    text_file.write("健康\n")
    text_file.write("產後\n")
    text_file.write("護理\n")
    text_file.write("板金\n")
    text_file.write("酒店\n")
    text_file.write("敬老院\n")
    text_file.write("票據\n")
    text_file.write("電機\n")
    text_file.write("美學\n")
    text_file.write("代工\n")
    text_file.write("生活\n")
    text_file.write("材料\n")
    text_file.write("台積電\n")
    text_file.write("外包\n")
    text_file.write("瓦斯\n")
    text_file.write("火車\n")
    text_file.write("不動產\n")
    text_file.write("薄膜\n")
    text_file.write("女中\n")
    text_file.write("市立\n")
    text_file.write("國立\n")
    text_file.write("私立\n")
    text_file.write("天然\n")
    text_file.write("酵母\n")
    text_file.write("集團\n")
    text_file.write("數位\n")
    text_file.write("豆漿\n")
    text_file.write("加工\n")
    text_file.write("禮品\n")
    text_file.write("水果\n")
    text_file.write("好事多\n")
    text_file.write("好市多\n")
    text_file.write("警察\n")
    text_file.write("警官\n")
    text_file.write("高職\n")
    text_file.write("商業\n")
    text_file.write("油行\n")
    text_file.write("化學\n")
    text_file.write("學校\n")
    text_file.write("檢驗\n")
    text_file.write("郵政\n")
    text_file.write("不動產\n")
    text_file.write("教會\n")
    text_file.write("投顧\n")
    text_file.write("照相\n")
    text_file.write("製版\n")
    text_file.write("藥廠\n")
    text_file.write("交通\n")
    text_file.write("投信\n")
    text_file.write("材料\n")
    text_file.write("協會\n")
    text_file.write("教養院\n")
    text_file.write("中心\n")
    text_file.write("內科\n")
    text_file.write("市場\n")
    text_file.write("牧場\n")
    text_file.write("料理\n")
    text_file.write("日月光\n")
    text_file.write("三商美邦\n")
    text_file.write("長庚\n")
    text_file.write("岱晉\n")

# %%
#!pip install jieba
import jieba
import jieba.analyse

# %%
jieba.load_userdict('vocabulary.txt')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\POPO\AppData\Local\Temp\jieba.cache
# Loading model cost 0.635 seconds.
# Prefix dict has been built succesfully.

# %%
def pad2(x):
    if len(x)==0:
        x=["nan","nan"]
    pad=x[0]
    while len(x)<2:
        x.append(pad)
    return x
def pad3(x):
    if len(x)==0:
        x=["nan","nan","nan"]
    pad=x[0]
    while len(x)<3:
        x.append(pad)
    return x
def pad4(x):
    if len(x)==0:
        x=["nan","nan","nan","nan"]
    pad=x[0]
    while len(x)<4:
        x.append(pad)
    return x

# %%
data["公司"]=data["k_a08a_1"].apply(lambda x:jieba.analyse.extract_tags(x, topK=2, withWeight=False, allowPOS=()))
data["公司"]=data["公司"].apply(pad2)
test["公司"]=test["k_a08a_1"].apply(lambda x:jieba.analyse.extract_tags(x, topK=2, withWeight=False, allowPOS=()))
test["公司"]=test["公司"].apply(pad2)

# %%
data["職稱"]=data["k_a08a_4"].apply(lambda x:jieba.analyse.extract_tags(x, topK=2, withWeight=False, allowPOS=()))
data["職稱"]=data["職稱"].apply(pad2)
test["職稱"]=test["k_a08a_4"].apply(lambda x:jieba.analyse.extract_tags(x, topK=2, withWeight=False, allowPOS=()))
test["職稱"]=test["職稱"].apply(pad2)

# %%
data["工作內容"]=data["k_a08a_5"].apply(lambda x:jieba.analyse.extract_tags(x, topK=4, withWeight=False, allowPOS=()))
data["工作內容"]=data["工作內容"].apply(pad4)
test["工作內容"]=test["k_a08a_5"].apply(lambda x:jieba.analyse.extract_tags(x, topK=4, withWeight=False, allowPOS=()))
test["工作內容"]=test["工作內容"].apply(pad4)

# %%
data["行業"]=data["k_a08a_2"].apply(lambda x:jieba.analyse.extract_tags(x, topK=3, withWeight=False, allowPOS=()))
data["行業"]=data["行業"].apply(pad3)
test["行業"]=test["k_a08a_2"].apply(lambda x:jieba.analyse.extract_tags(x, topK=3, withWeight=False, allowPOS=()))
test["行業"]=test["行業"].apply(pad3)

# %%
data["部門"]=[0]*len(data)
for i in range(len(data)):
    ans=jieba.analyse.extract_tags(data["k_a08a_3"][i], topK=1, withWeight=False, allowPOS=())
    if ans==[]:
        data["部門"][i]=[data["工作內容"][i][0]]
    else:
        data["部門"][i]=ans
test["部門"]=[0]*len(test)
for i in range(len(test)):
    ans=jieba.analyse.extract_tags(test["k_a08a_3"][i], topK=1, withWeight=False, allowPOS=())
    if ans==[]:
        test["部門"][i]=[test["工作內容"][i][0]]
    else:
        test["部門"][i]=ans
# Out:
# C:\Users\POPO\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\POPO\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\POPO\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# ...

# %% [markdown]
# # 準備放入Word2vector內的單詞

# %%
data["answer2"]=data["行業"]+data["公司"]
test["answer2"]=test["行業"]+test["公司"]

# %%
data["answer1"]=data["工作內容"]+data["職稱"]+data["行業"]+data["部門"]+data["工作內容"]+data["公司"]
test["answer1"]=test["工作內容"]+test["職稱"]+test["行業"]+test["部門"]+test["工作內容"]+test["公司"]

# %%
voc=list(test["answer1"])+list(test["answer2"])+list(data["answer1"])+list(data["answer2"])

# %% [markdown]
# # TF-idf

# %%
a1=pd.concat([data[["k_a08a_1","k_a08a_2","k_a08a_3","k_a08a_4","k_a08a_5"]]
              ,test[["k_a08a_1","k_a08a_2","k_a08a_3","k_a08a_4","k_a08a_5"]]],axis=0)
a1["total"]=a1["k_a08a_5"]+a1["k_a08a_1"]+a1["k_a08a_2"]+a1["k_a08a_3"]+a1["k_a08a_4"]+a1["k_a08a_5"]+a1["k_a08a_1"]
a1.head()
# Out:
#       k_a08a_1 k_a08a_2 k_a08a_3 k_a08a_4 k_a08a_5  \
# 0       大潤發總公司      大賣場       會計       會計     總計發票
# 1  台灣資生堂股份有限公司    化粧品販售              美容顧問  販售化粧品護膚
# 2         宏偉科技     Ic加工       品管             檢查完成品
# 3     台灣第一家塩酥雞       食物                       炸料收錢
# 4         统一超商    零售日用品                店員   收銀排貨售貨
#
#                                            total
# 0                    總計發票大潤發總公司大賣場會計會計總計發票大潤發總公司
# 1  販售化粧品護膚台灣資生堂股份有限公司化粧品販售美容顧問販售化粧品護膚台灣資生堂股份有限公司
# 2                       檢查完成品宏偉科技Ic加工品管檢查完成品宏偉科技
# 3                     炸料收錢台灣第一家塩酥雞食物炸料收錢台灣第一家塩酥雞
# 4                    收銀排貨售貨统一超商零售日用品店員收銀排貨售貨统一超商

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
def dummy(data):
    return str(data)
vectorizer =TfidfVectorizer(preprocessor=dummy)
tfidf = vectorizer.fit_transform(list(a1["total"].apply(lambda x:list(jieba.cut(x)))))
print(tfidf.shape)
# Out:
# (3943, 7117)

# %%
from sklearn.decomposition import TruncatedSVD
n_components = 2600
tsvd = TruncatedSVD(n_components=n_components)
tsvd_result = tsvd.fit_transform(tfidf)
explained_variance = tsvd.explained_variance_ratio_.sum()
# The svd explains only a tiny portion of the variance
print("Explained variance %f" % (explained_variance))
print(tsvd_result.shape)
# Out:
# Explained variance 0.953521
# (3943, 2600)

# %%
data["tsvd_result1"]=list(tsvd_result)[:3200]
test["tsvd_result1"]=list(tsvd_result)[3200:]
def transform(x):
    while len(x)<2600:
        x.append(0)
    return x
data["tsvd_result1"]=data["tsvd_result1"].apply(transform)
test["tsvd_result1"]=test["tsvd_result1"].apply(transform)

# %%
a1["totalnew"]=a1["k_a08a_1"]+a1["k_a08a_2"]+a1["k_a08a_3"]+a1["k_a08a_4"]+a1["k_a08a_5"]+a1["k_a08a_2"]+a1["k_a08a_1"]
a1.head()
# Out:
#       k_a08a_1 k_a08a_2 k_a08a_3 k_a08a_4 k_a08a_5  \
# 0       大潤發總公司      大賣場       會計       會計     總計發票
# 1  台灣資生堂股份有限公司    化粧品販售              美容顧問  販售化粧品護膚
# 2         宏偉科技     Ic加工       品管             檢查完成品
# 3     台灣第一家塩酥雞       食物                       炸料收錢
# 4         统一超商    零售日用品                店員   收銀排貨售貨
#
#                                            total  \
# 0                    總計發票大潤發總公司大賣場會計會計總計發票大潤發總公司
# 1  販售化粧品護膚台灣資生堂股份有限公司化粧品販售美容顧問販售化粧品護膚台灣資生堂股份有限公司
# 2                       檢查完成品宏偉科技Ic加工品管檢查完成品宏偉科技
# 3                     炸料收錢台灣第一家塩酥雞食物炸料收錢台灣第一家塩酥雞
# 4                    收銀排貨售貨统一超商零售日用品店員收銀排貨售貨统一超商
#
#                                       totalnew
# 0                   大潤發總公司大賣場會計會計總計發票大賣場大潤發總公司
# 1  台灣資生堂股份有限公司化粧品販售美容顧問販售化粧品護膚化粧品販售台灣資生堂股份有限公司
# 2                      宏偉科技Ic加工品管檢查完成品Ic加工宏偉科技
# 3                     台灣第一家塩酥雞食物炸料收錢食物台灣第一家塩酥雞
# 4                   统一超商零售日用品店員收銀排貨售貨零售日用品统一超商

# %%
vectorizer =TfidfVectorizer(preprocessor=dummy)
tfidf = vectorizer.fit_transform(list(a1["totalnew"].apply(lambda x:list(jieba.cut(x)))))
print(tfidf.shape)
# Out:
# (3943, 7384)

# %%
from sklearn.decomposition import TruncatedSVD
n_components = 2600
tsvd = TruncatedSVD(n_components=n_components)
tsvd_result = tsvd.fit_transform(tfidf)
explained_variance = tsvd.explained_variance_ratio_.sum()
# The svd explains only a tiny portion of the variance
print("Explained variance %f" % (explained_variance))
print(tsvd_result.shape)
# Out:
# Explained variance 0.958800
# (3943, 2600)

# %%
data["tsvd_result2"]=list(tsvd_result)[:3200]
test["tsvd_result2"]=list(tsvd_result)[3200:]
def transform(x):
    while len(x)<2600:
        x.append(0)
    return x
data["tsvd_result2"]=data["tsvd_result2"].apply(transform)
test["tsvd_result2"]=test["tsvd_result2"].apply(transform)

# %%
from gensim.models import Word2Vec
#mymodel = Word2Vec(voc*2,size=200, min_count=2,workers=4,sg=1)
#mymodel.save("modelnew")

# %%
model=Word2Vec.load('modelnew')

# %%
import numpy as np

# %%
def w2v_vector(text_list):
    new=[]
    for word in text_list:
        new=new+list(model[word])
    new=np.array(new,dtype=float)
    return new

# %%
data["answer1"]=data["answer1"].apply(w2v_vector)
data["answer2"]=data["answer2"].apply(w2v_vector)
test["answer1"]=test["answer1"].apply(w2v_vector)
test["answer2"]=test["answer2"].apply(w2v_vector)
# Out:
# C:\Users\POPO\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   after removing the cwd from sys.path.

# %%
new_train=[]
for i in range(len(data)):
    a1=data["answer1"][i]
    a1=list(a1)+list(data["tsvd_result1"][i])
    new_train.append(a1)

new_test=[]
for i in range(len(test)):
    a1=test["answer1"][i]
    a1=list(a1)+list(test["tsvd_result1"][i])
    new_test.append(a1)
    
print(np.array(new_train).shape)
print(np.array(new_test).shape)
# Out:
# (3200, 5800)
# (743, 5800)

# %%
new_train2=[]
for i in range(len(data)):
    a1=data["answer2"][i]
    a1=list(a1)+list(data["tsvd_result2"][i])
    new_train2.append(a1)
    
new_test2=[]
for i in range(len(test)):
    a1=test["answer2"][i]
    a1=list(a1)+list(test["tsvd_result2"][i])
    new_test2.append(a1)    
    
    
print(np.array(new_train2).shape)
print(np.array(new_test2).shape)
# Out:
# (3200, 3600)
# (743, 3600)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
data["a08a02"]=data["a08a02"].astype('category')
data["a08a01"]=data["a08a01"].astype('category')

# %%
X_train, X_test, y_train, y_test = train_test_split(new_train, np.array(data["a08a02"]), test_size=0.1, random_state=1)
x_train, x_test, Y_train, Y_test = train_test_split(new_train2, np.array(data["a08a01"]), test_size=0.1, random_state=1)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=12,k_neighbors=4)
X_train_res, y_train_res = sm.fit_sample(X_train, y_train)
sm = SMOTE(random_state=12,k_neighbors=5)
x_train_res, Y_train_res=sm.fit_sample(x_train,Y_train)

# %%
forest1 = RandomForestClassifier(criterion='entropy',n_estimators=2500, random_state=1,n_jobs=5)
forest1.fit(X_train_res, y_train_res)
y_pred = forest1.predict(X_test)
y_train_pred=forest1.predict(X_train)
print('Accuracy (forest): %.5f' % accuracy_score(y_train, y_train_pred))
print('Accuracy (forest): %.5f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy (forest): 0.99896
# Accuracy (forest): 0.62187

# %%
forest2 = RandomForestClassifier(criterion='entropy',n_estimators=2500, random_state=1,n_jobs=5)
forest2.fit(x_train_res, Y_train_res)
y_pred = forest2.predict(x_test)
y_train_pred=forest2.predict(x_train)
print('Accuracy (forest): %.5f' % accuracy_score(Y_train, y_train_pred))
print('Accuracy (forest): %.5f' % accuracy_score(Y_test, y_pred))
# Out:
# Accuracy (forest): 0.99896
# Accuracy (forest): 0.74062

# %%
#(0.74062+0.62187)*(1/2)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=12,k_neighbors=7)
X, y = sm.fit_sample(new_train, np.array(data["a08a02"]))
sm = SMOTE(random_state=12,k_neighbors=6)
x, Y =sm.fit_sample(new_train2, np.array(data["a08a01"]))

# %%
forest1 = RandomForestClassifier(criterion='entropy',n_estimators=3000, random_state=1,n_jobs=5)
forest1.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=3000, n_jobs=5,
#             oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
forest2 = RandomForestClassifier(criterion='entropy',n_estimators=3000, random_state=1,n_jobs=5)
forest2.fit(x, Y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=3000, n_jobs=5,
#             oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
a1=forest1.predict(new_test)
a2=forest2.predict(new_test2)

# %%
sample=pd.read_csv("sample_submission.csv")
sample.head()
# Out:
#              x01  prediction
# 0  100201_a08a01          85
# 1  100222_a08a01          85
# 2  101201_a08a01          85
# 3  102102_a08a01          85
# 4  102811_a08a01          85

# %%
final=list(a2)+list(a1)
sample["prediction"]=final
sample=sample.set_index("x01")
sample.head()
# Out:
#                prediction
# x01
# 100201_a08a01          32
# 100222_a08a01          29
# 101201_a08a01          56
# 102102_a08a01          25
# 102811_a08a01          47

# %%
sample.to_csv("C://Users//POPO//Desktop//predict.csv")
